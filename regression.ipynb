# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from model import MultipleRegression, standardize

# %%
df = pd.read_csv('advertising_and_sales_clean.csv')
df = df.drop(columns=['influencer'])
# print(df.head()) # 1000

# %matplotlib widget

df = standardize(df) # normalize

fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.scatter(df['tv'], df['radio'], df['sales'] ,s=5)

# %%
x = df['tv']
y = df['radio']
z = df['sales']
# Out:
# 0   -1.458073
# 1   -1.572994
# 2   -0.500400
# 3    1.108491
# 4   -1.496380
# Name: tv, dtype: float64
