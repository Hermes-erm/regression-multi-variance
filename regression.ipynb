# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from model import normalize

# %%
df = pd.read_csv('advertising_and_sales_clean.csv')
df = df.drop(columns=['influencer'])
print(df.head(10))
# Out:
#         tv     radio  social_media      sales
# 0  16000.0   6566.23       2907.98   54732.76
# 1  13000.0   9237.76       2409.57   46677.90
# 2  41000.0  15886.45       2913.41  150177.83
# 3  83000.0  30020.03       6922.30  298246.34
# 4  15000.0   8437.41       1406.00   56594.18
# 5  29000.0   9614.38       1027.16  105889.15
# 6  55000.0  24893.81       4273.60  198679.82
# 7  31000.0  17355.04       2289.85  108733.93
# 8  76000.0  24648.90       7130.12  270189.40
# 9  13000.0    431.13       2229.42   48280.58

# %%
data = normalize(df)
# sns.pairplot(data)
plt.scatter(x=data[data.columns[0]], y=data['sales'], s=20)
plt.scatter(x=data[data.columns[1]], y=data['sales'], s=20)
plt.scatter(x=data[data.columns[2]], y=data['sales'], s=20)
